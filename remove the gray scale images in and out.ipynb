# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import os
import glob
import h5py
import cv2

# %%
part_A_train = os.path.join(os.getcwd(),'ShanghaiTech\\part_A\\train_data\\images')
part_A_test = os.path.join(os.getcwd(),'ShanghaiTech\\part_A\\test_data\\images')
part_B_train = os.path.join(os.getcwd(),'ShanghaiTech\\part_B\\train_data\\images')
part_B_test = os.path.join(os.getcwd(),'ShanghaiTech\\part_B\\test_data\\images')

# %%
part_A_train_images = glob.glob(os.path.join(part_A_train,'*.jpg'))
part_A_test_images = glob.glob(os.path.join(part_A_test,'*.jpg'))
part_B_train_images = glob.glob(os.path.join(part_B_train,'*.jpg'))
part_B_test_images = glob.glob(os.path.join(part_B_test,'*.jpg'))
print(f'Shanghai Part A train -- total size {len(part_A_train_images)}')
print(f'Shanghai Part A test -- total size {len(part_A_test_images)}')
print(f'Shanghai Part B train -- total size {len(part_B_train_images)}')
print(f'Shanghai Part B test -- total size {len(part_B_test_images)}')
print(f'Total people counting images = {len(part_A_train_images)+len(part_A_test_images)+len(part_B_train_images)+len(part_B_test_images)}')
# Out:
# Shanghai Part A train -- total size 300
# Shanghai Part A test -- total size 182
# Shanghai Part B train -- total size 400
# Shanghai Part B test -- total size 316
# Total people counting images = 1198

# %%
def merging_all_images(list_of_images,list_names):
    
    final_paths = []
    
    for index,(path,name) in enumerate(zip(list_of_images,list_names),0):
        
        def extract_number(path):
            
            file_path = path.split('\\')[-1].split('.')[0].split('_')[1]
            
            return int(file_path)

        file_paths = sorted(path,key=extract_number)
        
        final_paths.append({name:file_paths})
        
    return final_paths

# %%
list_names = ["part_A_train_images","part_A_test_images","part_B_train_images","part_B_test_images"]
list_of_images_path = [part_A_train_images,part_A_test_images,part_B_train_images,part_B_test_images]

# %%
all_images_files = merging_all_images(list_of_images_path,list_names)
len(all_images_files)
# Out:
# 4

# %%
all_images_files
# Out:
# [{'part_A_train_images': ['C:\\Users\\farheen.syed_iprotec\\Desktop\\python\\ShanghaiTech\\part_A\\train_data\\images\\IMG_1.jpg',
#    'C:\\Users\\farheen.syed_iprotec\\Desktop\\python\\ShanghaiTech\\part_A\\train_data\\images\\IMG_2.jpg',
#    'C:\\Users\\farheen.syed_iprotec\\Desktop\\python\\ShanghaiTech\\part_A\\train_data\\images\\IMG_3.jpg',
#    'C:\\Users\\farheen.syed_iprotec\\Desktop\\python\\ShanghaiTech\\part_A\\train_data\\images\\IMG_4.jpg',
#    'C:\\Users\\farheen.syed_iprotec\\Desktop\\python\\ShanghaiTech\\part_A\\train_data\\images\\IMG_5.jpg',
#    'C:\\Users\\farheen.syed_iprotec\\Desktop\\python\\ShanghaiTech\\part_A\\train_data\\images\\IMG_6.jpg',
#    'C:\\Users\\farheen.syed_iprotec\\Desktop\\python\\ShanghaiTech\\part_A\\train_data\\images\\IMG_7.jpg',
#    'C:\\Users\\farheen.syed_iprotec\\Desktop\\python\\ShanghaiTech\\part_A\\train_data\\images\\IMG_8.jpg',
# ...

# %%
for path in list_of_images_path[:2]:
    
    for image in path:
        
        image_file = plt.imread(image)
        image_shape = image_file.shape
        
        if len(image_shape) == 3:
            
            continue
            
        else:
            os.remove(image)
            print(f'Gray File path removed Successfully {image}')
# Out:
# Gray File path removed Successfully C:\Users\farheen.syed_iprotec\Desktop\python\ShanghaiTech\part_A\train_data\images\IMG_106.jpg
# Gray File path removed Successfully C:\Users\farheen.syed_iprotec\Desktop\python\ShanghaiTech\part_A\train_data\images\IMG_13.jpg
# Gray File path removed Successfully C:\Users\farheen.syed_iprotec\Desktop\python\ShanghaiTech\part_A\train_data\images\IMG_130.jpg
# Gray File path removed Successfully C:\Users\farheen.syed_iprotec\Desktop\python\ShanghaiTech\part_A\train_data\images\IMG_153.jpg
# Gray File path removed Successfully C:\Users\farheen.syed_iprotec\Desktop\python\ShanghaiTech\part_A\train_data\images\IMG_17.jpg
# Gray File path removed Successfully C:\Users\farheen.syed_iprotec\Desktop\python\ShanghaiTech\part_A\train_data\images\IMG_205.jpg
# Gray File path removed Successfully C:\Users\farheen.syed_iprotec\Desktop\python\ShanghaiTech\part_A\train_data\images\IMG_213.jpg
# ...

# %%
list_of_deleting = [r"C:\Users\farheen.syed_iprotec\Desktop\python\ShanghaiTech\part_A\train_data\ground_truth-h5\IMG_106.h5",
                    r"C:\Users\farheen.syed_iprotec\Desktop\python\ShanghaiTech\part_A\train_data\ground_truth-h5\IMG_13.h5",
                    r"C:\Users\farheen.syed_iprotec\Desktop\python\ShanghaiTech\part_A\train_data\ground_truth-h5\IMG_130.h5",
                    r"C:\Users\farheen.syed_iprotec\Desktop\python\ShanghaiTech\part_A\train_data\ground_truth-h5\IMG_153.h5",
                    r"C:\Users\farheen.syed_iprotec\Desktop\python\ShanghaiTech\part_A\train_data\ground_truth-h5\IMG_17.h5",
                    r"C:\Users\farheen.syed_iprotec\Desktop\python\ShanghaiTech\part_A\train_data\ground_truth-h5\IMG_205.h5",
                    r"C:\Users\farheen.syed_iprotec\Desktop\python\ShanghaiTech\part_A\train_data\ground_truth-h5\IMG_213.h5",
                    r"C:\Users\farheen.syed_iprotec\Desktop\python\ShanghaiTech\part_A\train_data\ground_truth-h5\IMG_298.h5",
                    r"C:\Users\farheen.syed_iprotec\Desktop\python\ShanghaiTech\part_A\train_data\ground_truth-h5\IMG_35.h5",
                    r"C:\Users\farheen.syed_iprotec\Desktop\python\ShanghaiTech\part_A\train_data\ground_truth-h5\IMG_4.h5",
                    r"C:\Users\farheen.syed_iprotec\Desktop\python\ShanghaiTech\part_A\train_data\ground_truth-h5\IMG_40.h5"]

# %%
for image in list_of_images_path[0]:

    image_output = image.replace('jpg','h5').replace('images','ground-truth-h5')

    if image_output not in list_of_deleting:
        continue
    else:
        os.remove(image_output)
        print(f'Gray File path removed Successfully {image}.h5')
